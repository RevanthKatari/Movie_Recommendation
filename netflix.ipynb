# %%
# !pip install apyori
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv('netflix.csv',header=None)
recommendations=[]

for i in range(0,len(dataset)):
    recommendations.append([str(dataset.values[i,j]) for j in range(0,20)])

# %%
print(recommendations)
# Out:
# [['The Lord of the rings', 'Cinema Paradiso', 'Se7en', 'Avengers: Infinity War', 'The Shining', 'High and Low ', 'Terminator 2: Judgment Day', 'Toy Story', 'City of God', 'Witness for the Prosecution', '12 Angry Men', 'Whiplash', 'Black Panther', 'Hamilton', 'The Dark Knight', 'Once Upon a Time in the West', 'The Great Dictator', 'Back to the Future', 'Aliens', 'Comedy nights with Kapil'], ['The Shawshank Redemption', 'Fight Club', 'Pulp Fiction', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['The Godfather', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['The Godfather: Part II', 'Se7en', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan'], ['The Dark Knight', 'The Intouchables', "One Flew Over the Cuckoo's Nest", 'whole wheat Star Wars: Episode V - 
# ...

# %%
from apyori import apriori
movie_rec=apriori(transactions=recommendations,min_support=0.002,min_confidence=0.2,min_lift=3,min_length=2,max_length=5)

# %%
results=list(movie_rec)
results
# Out:
# [RelationRecord(items=frozenset({'3 Idiots', 'The Pianist'}), support=0.0021424745581146223, ordered_statistics=[OrderedStatistic(items_base=frozenset({'3 Idiots'}), items_add=frozenset({'The Pianist'}), confidence=0.3076923076923077, lift=3.2273120138288682)]),
#  RelationRecord(items=frozenset({'American History X', 'The Good, the Bad and the Ugly'}), support=0.0020085698982324584, ordered_statistics=[OrderedStatistic(items_base=frozenset({'American History X'}), items_add=frozenset({'The Good, the Bad and the Ugly'}), confidence=0.25862068965517243, lift=3.2189655172413794)]),
#  RelationRecord(items=frozenset({'Black Panther', 'Captain America'}), support=0.0033476164970540974, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Captain America'}), items_add=frozenset({'Black Panther'}), confidence=0.24509803921568626, lift=5.141551002423442)]),
# ...

# %%
def inspect(results):
    movie_1=[tuple(result[2][0][0])[0] for result in results]
    movie_2=[tuple(result[2][0][1])[0] for result in results]
    supports=[results[1] for result in results]
    confidences=[result[2][0][2] for result in results]
    lifts=[result[2][0][3] for result in results]
    return list(zip(movie_1,movie_2,supports,confidences,lifts))
DataFrame_intelligence=pd.DataFrame(inspect(results),columns=['Movie 1','Movie 2','Support','Confidence','Lifts'])

# %%
DataFrame_intelligence
# Out:
#                                                Movie 1  \
# 0                                             3 Idiots
# 1                                   American History X
# 2                                      Captain America
# 3                                      Game of thrones
# 4                                    Kanan Gill Comedy
# ..                                                 ...
# 498                                   The Intouchables
# 499                                   The Intouchables
# 500                                   The Intouchables
# 501                                   The Intouchables
# 502  The Lord of the Rings: The Fellowship of the Ring
#
#                             Movie 2  \
# 0                       The Pianist
# 1    The Good, the Bad and the Ugly
# 2                     Black Panther
# 3          Comedy nights with Kapil
# 4          Comedy nights with Kapil
# ..                              ...
# 498                             nan
# ...
